# %% [markdown]
# ## Hello world example

# %%
run PythonDemo
# Out:
# Hello world

# %%
5+7
# Out:
# 12

# %%
def hello2():
    """Print "Hello world" and return no output."""
    print("Hello world too")

# %%
hello2()
# Out:
# Hello world too
